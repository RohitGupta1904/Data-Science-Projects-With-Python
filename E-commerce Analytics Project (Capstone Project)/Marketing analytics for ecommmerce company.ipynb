# %%
import pandas as pd

# %%
import numpy as np

# %%
import datetime as dt

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# #Importing and EDA

# %%
#importing and understanding customers dataset
customers=pd.read_csv("C:/Users/rg191/Downloads/Hp backup/Mehak Mam/Python by Mehak mam/Case Study/4 E-commerce Analytics Project/CUSTOMERS.csv")
customers=customers.dropna(axis=0, how='all')
customers.head(5)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix customer_city  customer_state
# 0                     14409      Adilabad  Andhra Pradesh
# 1                      9790         Adoni  Andhra Pradesh
# 2                      1151  Akkarampalle  Andhra Pradesh
# 3                      8775   Akkayapalle  Andhra Pradesh
# 4                     13056         Alwal  Andhra Pradesh

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
#importing and understanding sellers dataset
sellers=pd.read_csv("C:/Users/rg191/Downloads/Hp backup/Mehak Mam/Python by Mehak mam/Case Study/4 E-commerce Analytics Project/SELLERS.csv")
sellers=sellers.dropna(axis=0, how='all')
sellers.head(5)
# Out:
#                           seller_id  seller_zip_code_prefix   seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023         Alwal
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13023         Alwal
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031     Badepalle
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195  Akkarampalle
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914       Koratla
#
#      seller_state
# 0  Andhra Pradesh
# 1  Andhra Pradesh
# 2  Andhra Pradesh
# 3  Andhra Pradesh
# 4  Andhra Pradesh

# %%
sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3038 non-null   object
#  3   seller_state            3038 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
#importing and understanding products dataset 
products=pd.read_csv("C:/Users/rg191/Downloads/Hp backup/Mehak Mam/Python by Mehak mam/Case Study/4 E-commerce Analytics Project/PRODUCTS.csv")
products=products.dropna(axis=0, how='all')
products.head(5)
# Out:
#                          product_id product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             Perfumery
# 1  3aa071139cb16b67ca9e5dea641aaa2f                   Art
# 2  96bd76ec8810374ed1b65e291975717f        Sports_Leisure
# 3  cef67bcfe19066a932b7673e239eb23d                  Baby
# 4  9dc1a7de274444849c219cff195d0b71            Housewares
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32328 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
#importing and understanding order dataset 
orders=pd.read_csv("C:/Users/rg191/Downloads/Hp backup/Mehak Mam/Python by Mehak mam/Case Study/4 E-commerce Analytics Project/ORDERS.csv")
orders=orders.dropna(axis=0, how='all')
orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders['order_purchase_timestamp']=orders['order_purchase_timestamp'].apply(lambda x : pd.to_datetime(x, format='%m/%d/%Y %H:%M'))
orders['order_delivered_customer_date']=orders['order_delivered_customer_date'].apply(lambda x : pd.to_datetime(x, format='%m/%d/%Y %H:%M'))
orders['order_estimated_delivery_date']=orders['order_estimated_delivery_date'].apply(lambda x : pd.to_datetime(x, format='%m/%d/%Y %H:%M'))
orders['month']=orders.order_purchase_timestamp.apply(lambda x : x.month)
orders['year']=orders.order_purchase_timestamp.apply(lambda x : x.year)
orders=orders.dropna(axis=0, how='all')
orders.head(2)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered      2017-10-02 10:56:00   10/2/2017 11:07
# 1    delivered      2018-07-24 20:41:00    7/26/2018 3:24
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0              10/4/2017 19:55           2017-10-10 21:25:00
# 1              7/26/2018 14:31           2018-08-07 15:27:00
#
#   order_estimated_delivery_date  month  year
# 0                    2017-10-18     10  2017
# 1                    2018-08-13      7  2018

# %%
# importing and understandig oreder items dataset
order_items=pd.read_csv("C:/Users/rg191/Downloads/Hp backup/Mehak Mam/Python by Mehak mam/Case Study/4 E-commerce Analytics Project/ORDER_ITEMS.csv")
order_items=order_items.dropna(axis=0, how='all')
order_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_items['shipping_limit_date']=order_items['shipping_limit_date'].apply(lambda x : pd.to_datetime(x, format='%m/%d/%Y %H:%M'))
order_items['net_price']=order_items.price + order_items.freight_value
order_items=order_items.dropna(axis=0, how='all')
order_items.head(2)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
#
#   shipping_limit_date  price  freight_value  net_price
# 0 2017-09-19 09:45:00   58.9          13.29      72.19
# 1 2017-05-03 11:05:00  239.9          19.93     259.83

# %%
#importing and understanding order payment dataset 
order_Payments=pd.read_csv("C:/Users/rg191/Downloads/Hp backup/Mehak Mam/Python by Mehak mam/Case Study/4 E-commerce Analytics Project/ORDER_PAYMENTS.csv")
order_Payments=order_Payments.dropna(axis=0, how='all')
order_Payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1          UPI
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1          UPI
#
#         payment_installments  payment_value
# ...

# %%
order_Payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
#importing and understanding order review rating dataset
order_review_ratings=pd.read_csv("C:/Users/rg191/Downloads/Hp backup/Mehak Mam/Python by Mehak mam/Case Study/4 E-commerce Analytics Project/ORDER_REVIEW_RATINGS.csv")
order_review_ratings.dropna(axis=0, how='all')
order_review_ratings.head(5)
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_creation_date review_answer_timestamp
# 0             4       1/18/2018 0:00         1/18/2018 21:46
# 1             5       3/10/2018 0:00          3/11/2018 3:05
# 2             5       2/17/2018 0:00         2/18/2018 14:36
# 3             5       4/21/2017 0:00         4/21/2017 22:02
# 4             5        3/1/2018 0:00          3/2/2018 10:26

# %%
#importing and understanding geographical location dataset
Geo_location=pd.read_csv("C:/Users/rg191/Downloads/Hp backup/Mehak Mam/Python by Mehak mam/Case Study/4 E-commerce Analytics Project/GEO_LOCATION.csv")
Geo_location=Geo_location.dropna(axis=0, how='all')
Geo_location
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                             1037       -23.545621       -46.639292
# 1                             1046       -23.546081       -46.644820
# 2                             1041       -23.544392       -46.639499
# 3                             1035       -23.541578       -46.641607
# 4                             1012       -23.547762       -46.635361
# ...                            ...              ...              ...
# 19010                        99955       -28.107588       -52.144019
# 19011                        99970       -28.345143       -51.876926
# 19012                        99910       -27.863500       -52.084760
# 19013                        99920       -27.858716       -52.300403
# 19014                        99952       -28.160371       -51.936922
#
#       geolocation_city geolocation_state
# 0         Akkarampalle    Andhra Pradesh
# 1         Akkarampalle    Andhra Pradesh
# ...

# %%
Geo_location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19015 entries, 0 to 19014
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   geolocation_zip_code_prefix  19015 non-null  int64
#  1   geolocation_lat              19015 non-null  float64
#  2   geolocation_lng              19015 non-null  float64
#  3   geolocation_city             19015 non-null  object
#  4   geolocation_state            19015 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 742.9+ KB

# %% [markdown]
# #### Q1. Perform Detailed exploratory analysis
# #### 1.a Define & calculate high level metrics like (Total Revenue, Total quantity, Total products, Total categories, Total sellers, Total locations, Total channels, Total payment methods etc…)

# %%
# Total number of customers
Tot_Customers=customers.customer_id.nunique()
Tot_Customers
# Out:
# 99441

# %%
# Total number of sellers
Tot_No_sellers=sellers.seller_id.nunique()
Tot_No_sellers
# Out:
# 3095

# %%
# Total No of products
Tot_No_products=products.product_id.nunique()
Tot_No_products
# Out:
# 32951

# %%
# Total no. of product category
Tot_No_category=products.product_category_name.nunique()
Tot_No_category
# Out:
# 71

# %%
# Total no. of orders
Total_No_orders=orders.order_id.nunique()
Total_No_orders
# Out:
# 99441

# %%
# Total amount of revenue generated
Tot_revenue=order_Payments.payment_value.sum()
Tot_revenue
# Out:
# 16008872.12

# %%
# Total no. of payment channel
Tot_payment_type=order_Payments.payment_type.nunique()
Tot_payment_type
# Out:
# 5

# %%
# Total no. of customer state
Tot_No_customer_state=customers.customer_state.nunique()
Tot_No_customer_state
# Out:
# 20

# %%
# Total no. of customer cities
Tot_No_customer_city=customers.customer_city.nunique()
Tot_No_customer_city
# Out:
# 4119

# %%
# Total no. of seller state
Tot_No_seller_state=sellers.seller_state.nunique()
Tot_No_seller_state
# Out:
# 19

# %%
# Total no. of seller city
Tot_No_seller_city=sellers.seller_city.nunique()
Tot_No_seller_city
# Out:
# 534

# %% [markdown]
# #### 1.b Understanding how many new customers acquired every month

# %%
cust_order=pd.merge(customers, orders, 'inner', on='customer_id')
cust_order.head(5)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix customer_city  customer_state  \
# 0                     14409      Adilabad  Andhra Pradesh
# 1                      9790         Adoni  Andhra Pradesh
# 2                      1151  Akkarampalle  Andhra Pradesh
# 3                      8775   Akkayapalle  Andhra Pradesh
# 4                     13056         Alwal  Andhra Pradesh
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:00
# ...

# %%
# customer monthwise first purchase date
month_cust_date_min=cust_order.groupby(['year', 'month', 'customer_unique_id'])['order_purchase_timestamp'].min().reset_index()
month_cust_date_min.head(5)
# Out:
#    year  month                customer_unique_id order_purchase_timestamp
# 0  2016      9  009b0127b727ab0ba422f6d9604487c7      2016-09-13 15:24:00
# 1  2016      9  4854e9b3feff728c13ee5fc7d1547e92      2016-09-05 00:15:00
# 2  2016      9  830d5b7aaa3b6f1e9ad63703bec97d23      2016-09-15 12:16:00
# 3  2016      9  b7d76e111c89f7ebf14761390f0f7d17      2016-09-04 21:15:00
# 4  2016     10  0032c76b20340da25249092a268ce66c      2016-10-06 11:32:00

# %%
# customer overall first purchase date
cust_date_min=cust_order.groupby('customer_unique_id')['order_purchase_timestamp'].min().reset_index()
cust_date_min.head(5)
# Out:
#                  customer_unique_id order_purchase_timestamp
# 0  0000366f3b9a7992bf8c76cfdf3221e2      2018-05-10 10:56:00
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f      2018-05-07 11:11:00
# 2  0000f46a3911fa3c0805444483337064      2017-03-10 21:05:00
# 3  0000f6ccb0745a6a4b88665a16c9f078      2017-10-12 20:29:00
# 4  0004aac84e0df4da2b147fca70cf8255      2017-11-14 19:45:00

# %%
cust_old_new=pd.merge(month_cust_date_min, cust_date_min, 'inner', 'customer_unique_id')
cust_old_new.head(5)
# Out:
#    year  month                customer_unique_id order_purchase_timestamp_x  \
# 0  2016      9  009b0127b727ab0ba422f6d9604487c7        2016-09-13 15:24:00
# 1  2016      9  4854e9b3feff728c13ee5fc7d1547e92        2016-09-05 00:15:00
# 2  2016      9  830d5b7aaa3b6f1e9ad63703bec97d23        2016-09-15 12:16:00
# 3  2016      9  b7d76e111c89f7ebf14761390f0f7d17        2016-09-04 21:15:00
# 4  2016     10  0032c76b20340da25249092a268ce66c        2016-10-06 11:32:00
#
#   order_purchase_timestamp_y
# 0        2016-09-13 15:24:00
# 1        2016-09-05 00:15:00
# 2        2016-09-15 12:16:00
# 3        2016-09-04 21:15:00
# 4        2016-10-06 11:32:00

# %%
# Creating new variable type of customer(old/new) by comparing customer's month first purchase date with cutomer's overall first purchase date
cust_old_new['type']=np.where(cust_old_new.order_purchase_timestamp_y < cust_old_new.order_purchase_timestamp_x, 'old', 'new')
cust_old_new.head(5)
# Out:
#    year  month                customer_unique_id order_purchase_timestamp_x  \
# 0  2016      9  009b0127b727ab0ba422f6d9604487c7        2016-09-13 15:24:00
# 1  2016      9  4854e9b3feff728c13ee5fc7d1547e92        2016-09-05 00:15:00
# 2  2016      9  830d5b7aaa3b6f1e9ad63703bec97d23        2016-09-15 12:16:00
# 3  2016      9  b7d76e111c89f7ebf14761390f0f7d17        2016-09-04 21:15:00
# 4  2016     10  0032c76b20340da25249092a268ce66c        2016-10-06 11:32:00
#
#   order_purchase_timestamp_y type
# 0        2016-09-13 15:24:00  new
# 1        2016-09-05 00:15:00  new
# 2        2016-09-15 12:16:00  new
# 3        2016-09-04 21:15:00  new
# 4        2016-10-06 11:32:00  new

# %%
# Monthwise no. of new and existing customer
monwise_old_new=pd.crosstab(index=[cust_old_new['year'], cust_old_new['month']], columns=cust_old_new.type, values=cust_old_new.customer_unique_id, aggfunc='count').reset_index()
monwise_old_new.columns=['year', 'month', 'new', 'old']
monwise_old_new
# Out:
#     year  month     new    old
# 0   2016      9     4.0    NaN
# 1   2016     10   321.0    NaN
# 2   2016     12     1.0    NaN
# 3   2017      1   764.0    1.0
# 4   2017      2  1752.0    3.0
# 5   2017      3  2636.0    6.0
# 6   2017      4  2352.0   20.0
# 7   2017      5  3596.0   29.0
# 8   2017      6  3139.0   41.0
# 9   2017      7  3894.0   53.0
# 10  2017      8  4184.0   62.0
# 11  2017      9  4130.0   82.0
# 12  2017     10  4470.0   91.0
# 13  2017     11  7304.0  126.0
# 14  2017     12  5487.0  116.0
# 15  2018      1  7025.0  141.0
# 16  2018      2  6451.0  118.0
# 17  2018      3  6965.0  150.0
# 18  2018      4  6711.0  171.0
# 19  2018      5  6622.0  192.0
# 20  2018      6  5940.0  188.0
# 21  2018      7  6071.0  159.0
# 22  2018      8  6271.0  189.0
# 23  2018      9     5.0    9.0
# 24  2018     10     1.0    3.0

# %%
# Monthwise no. of new customers
monthly_cust_new=monwise_old_new.loc[ : , ['year', 'month', 'new']]
monthly_cust_new.columns=['year', 'month', 'new_cust']
monthly_cust_new
# Out:
#     year  month  new_cust
# 0   2016      9       4.0
# 1   2016     10     321.0
# 2   2016     12       1.0
# 3   2017      1     764.0
# 4   2017      2    1752.0
# 5   2017      3    2636.0
# 6   2017      4    2352.0
# 7   2017      5    3596.0
# 8   2017      6    3139.0
# 9   2017      7    3894.0
# 10  2017      8    4184.0
# 11  2017      9    4130.0
# 12  2017     10    4470.0
# 13  2017     11    7304.0
# 14  2017     12    5487.0
# 15  2018      1    7025.0
# 16  2018      2    6451.0
# 17  2018      3    6965.0
# 18  2018      4    6711.0
# 19  2018      5    6622.0
# 20  2018      6    5940.0
# 21  2018      7    6071.0
# 22  2018      8    6271.0
# 23  2018      9       5.0
# 24  2018     10       1.0

# %% [markdown]
# #### 2nd way for ques 1.b

# %%
 cust_month = cust_order.loc[:, ['customer_unique_id', 'year', 'month']].sort_values(by=['year', 'month'], ascending=[True, True], ignore_index=True)

# %%
cust_month.drop_duplicates(subset='customer_unique_id' , inplace= True)

# %%
new_cust_monthly = cust_month.groupby(['year', 'month'])[['customer_unique_id']].count().reset_index()
new_cust_monthly.columns=['year', 'month', 'new customers']    
new_cust_monthly
# Out:
#     year  month  new customers
# 0   2016      9              4
# 1   2016     10            321
# 2   2016     12              1
# 3   2017      1            764
# 4   2017      2           1752
# 5   2017      3           2636
# 6   2017      4           2352
# 7   2017      5           3596
# 8   2017      6           3139
# 9   2017      7           3894
# 10  2017      8           4184
# 11  2017      9           4130
# 12  2017     10           4470
# 13  2017     11           7304
# 14  2017     12           5487
# 15  2018      1           7025
# 16  2018      2           6451
# 17  2018      3           6965
# 18  2018      4           6711
# 19  2018      5           6622
# 20  2018      6           5940
# 21  2018      7           6071
# 22  2018      8           6271
# 23  2018      9              5
# 24  2018     10              1

# %% [markdown]
# #### 1.c Understand the retention of customers on month on month basis

# %%
monthly_cust_retention=monwise_old_new.loc[ : , ['year', 'month', 'old']]
monthly_cust_retention.columns=['year', 'month', 'retented_cust']
monthly_cust_retention
# Out:
#     year  month  retented_cust
# 0   2016      9            NaN
# 1   2016     10            NaN
# 2   2016     12            NaN
# 3   2017      1            1.0
# 4   2017      2            3.0
# 5   2017      3            6.0
# 6   2017      4           20.0
# 7   2017      5           29.0
# 8   2017      6           41.0
# 9   2017      7           53.0
# 10  2017      8           62.0
# 11  2017      9           82.0
# 12  2017     10           91.0
# 13  2017     11          126.0
# 14  2017     12          116.0
# 15  2018      1          141.0
# 16  2018      2          118.0
# 17  2018      3          150.0
# 18  2018      4          171.0
# 19  2018      5          192.0
# 20  2018      6          188.0
# 21  2018      7          159.0
# 22  2018      8          189.0
# 23  2018      9            9.0
# 24  2018     10            3.0

# %% [markdown]
# #### 1.d How the revenues from existing/new customers on month on month basis

# %%
cust_order_item=pd.merge(cust_order, order_items, 'inner', 'order_id')
cust_order_item.head(5)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix customer_city  customer_state  \
# 0                     14409      Adilabad  Andhra Pradesh
# 1                      9790         Adoni  Andhra Pradesh
# 2                      1151  Akkarampalle  Andhra Pradesh
# 3                      8775   Akkayapalle  Andhra Pradesh
# 4                     13056         Alwal  Andhra Pradesh
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:00
# ...

# %%
cust_order_revenue=cust_order_item.groupby(['year', 'month', 'customer_unique_id'])[['net_price', 'product_id']].agg({'net_price': 'sum', 'product_id': 'count'}).reset_index()
cust_order_revenue.columns=['year', 'month', 'customer_unique_id', 'net_price', 'qty']
cust_order_revenue
# Out:
#        year  month                customer_unique_id  net_price  qty
# 0      2016      9  4854e9b3feff728c13ee5fc7d1547e92      75.06    1
# 1      2016      9  830d5b7aaa3b6f1e9ad63703bec97d23     143.46    3
# 2      2016      9  b7d76e111c89f7ebf14761390f0f7d17     136.23    2
# 3      2016     10  0032c76b20340da25249092a268ce66c     144.94    1
# 4      2016     10  01f156677184504063bd19739f924af1     784.80    1
# ...     ...    ...                               ...        ...  ...
# 97314  2018      8  ffc4e1cd8aa220763480d0a18157c45d     147.14    1
# 97315  2018      8  ffe204b1bb8026741b839085b2fd10f2     156.70    1
# 97316  2018      8  ffec490ab531184a483efe2eedd68908      57.98    1
# 97317  2018      8  fff96bc586f78b1f070da28c4977e810      63.42    1
# 97318  2018      9  ff22e30958c13ffe219db7d711e8f564     166.46    1
#
# [97319 rows x 5 columns]

# %%
cust_revenue=pd.merge(cust_old_new, cust_order_revenue, 'inner', ['year', 'month', 'customer_unique_id'])
cust_revenue
# Out:
#        year  month                customer_unique_id  \
# 0      2016      9  4854e9b3feff728c13ee5fc7d1547e92
# 1      2016      9  830d5b7aaa3b6f1e9ad63703bec97d23
# 2      2016      9  b7d76e111c89f7ebf14761390f0f7d17
# 3      2016     10  0032c76b20340da25249092a268ce66c
# 4      2016     10  01f156677184504063bd19739f924af1
# ...     ...    ...                               ...
# 97314  2018      8  ffc39051848c3ef2be36d1513aa3ad17
# 97315  2018      8  ffc4e1cd8aa220763480d0a18157c45d
# 97316  2018      8  ffe204b1bb8026741b839085b2fd10f2
# 97317  2018      8  ffec490ab531184a483efe2eedd68908
# 97318  2018      8  fff96bc586f78b1f070da28c4977e810
#
#       order_purchase_timestamp_x order_purchase_timestamp_y type  net_price  \
# 0            2016-09-05 00:15:00        2016-09-05 00:15:00  new      75.06
# 1            2016-09-15 12:16:00        2016-09-15 12:16:00  new     143.46
# 2            2016-09-04 21:15:00        2016-09-04 21:15:00  new     136.23
# ...

# %%
# Monthwise revenue of new and existing customers
cust_type_revenue=cust_revenue.pivot_table(index=['year', 'month'], columns= 'type', values='net_price', aggfunc='sum').reset_index()
cust_type_revenue.columns=['year', 'month', 'new_cust_revenue', 'existing_cust_revenue']
cust_type_revenue
# Out:
#     year  month  new_cust_revenue  existing_cust_revenue
# 0   2016      9            354.75                    NaN
# 1   2016     10          56808.84                    NaN
# 2   2016     12             19.62                    NaN
# 3   2017      1         137168.87                  19.62
# 4   2017      2         286109.79                 170.83
# 5   2017      3         431397.77                 650.82
# 6   2017      4         409855.64                2566.60
# 7   2017      5         581151.85                5039.10
# 8   2017      6         496933.39                6029.65
# 9   2017      7         574935.67               10035.95
# 10  2017      8         656910.93               11293.67
# 11  2017      9         708096.79               12302.12
# 12  2017     10         755434.15               13878.22
# 13  2017     11        1161028.82               18114.95
# 14  2017     12         844369.66               19177.57
# ...

# %%
# Monthwise new customer revenue
cust_new_revenue=cust_type_revenue.loc[ : , ['year', 'month', 'new_cust_revenue']]
cust_new_revenue
# Out:
#     year  month  new_cust_revenue
# 0   2016      9            354.75
# 1   2016     10          56808.84
# 2   2016     12             19.62
# 3   2017      1         137168.87
# 4   2017      2         286109.79
# 5   2017      3         431397.77
# 6   2017      4         409855.64
# 7   2017      5         581151.85
# 8   2017      6         496933.39
# 9   2017      7         574935.67
# 10  2017      8         656910.93
# 11  2017      9         708096.79
# 12  2017     10         755434.15
# 13  2017     11        1161028.82
# 14  2017     12         844369.66
# 15  2018      1        1085165.71
# 16  2018      2         970509.35
# 17  2018      3        1134203.79
# 18  2018      4        1132729.76
# 19  2018      5        1120483.46
# 20  2018      6         992112.29
# 21  2018      7        1033756.69
# 22  2018      8         979949.20
# 23  2018      9               NaN

# %%
# Monthwise existing customer revenue 
cust_existing_revenue=cust_type_revenue.loc[ : , ['year', 'month', 'existing_cust_revenue']]
cust_existing_revenue
# Out:
#     year  month  existing_cust_revenue
# 0   2016      9                    NaN
# 1   2016     10                    NaN
# 2   2016     12                    NaN
# 3   2017      1                  19.62
# 4   2017      2                 170.83
# 5   2017      3                 650.82
# 6   2017      4                2566.60
# 7   2017      5                5039.10
# 8   2017      6                6029.65
# 9   2017      7               10035.95
# 10  2017      8               11293.67
# 11  2017      9               12302.12
# 12  2017     10               13878.22
# 13  2017     11               18114.95
# 14  2017     12               19177.57
# 15  2018      1               22136.18
# 16  2018      2               16399.61
# 17  2018      3               20923.03
# 18  2018      4               26968.28
# 19  2018      5               29298.36
# 20  2018      6               30564.82
# 21  2018      7               24971.34
# 22  2018      8               23359.27
# ...

# %% [markdown]
# #### 1.e  Understand the trends/seasonality of sales, quantity by category, location, month, week, day, time, channel, payment method etc…

# %%
# Monthwise revenue and qty sold 
year_mon_revenue=cust_order_revenue.groupby(['year', 'month'])[['net_price', 'qty']].agg({'net_price': 'sum', 'qty': 'count'})
year_mon_revenue.columns=['revenue', 'qty']
year_mon_revenue
# Out:
#                revenue   qty
# year month
# 2016 9          354.75     3
#      10       56808.84   305
#      12          19.62     1
# 2017 1       137188.49   755
#      2       286280.62  1708
#      3       432048.59  2601
#      4       412422.24  2359
#      5       586190.95  3588
#      6       502963.04  3154
#      7       584971.62  3894
#      8       668204.60  4211
#      9       720398.91  4170
#      10      769312.37  4501
#      11     1179143.77  7342
#      12      863547.23  5557
# 2018 1      1107301.89  7120
#      2       986908.96  6537
#      3      1155126.82  7096
#      4      1159698.04  6878
#      5      1149781.82  6795
#      6      1022677.11  6121
#      7      1058728.03  6211
#      8      1003308.47  6411
#      9          166.46     1

# %%
revenue_plot=year_mon_revenue.plot(kind='bar', y='revenue',figsize=(15, 6), width =0.4)
for c in revenue_plot.containers:
    revenue_plot.bar_label(c, label_type='edge', rotation=90, fontsize=10)
plt.ylabel('sales')
plt.ticklabel_format(style='plain', axis='y')
plt.yticks(np.arange(0, 1650000, 150000))
plt.title('Yearly basis monthwise revenue', fontsize='15', fontweight='bold')
plt.show()

# %%
revenue_plot=year_mon_revenue.plot(kind='bar', y='qty',figsize=(15, 6), width =0.4)
for c in revenue_plot.containers:
    revenue_plot.bar_label(c, label_type='edge', rotation=90, fontsize=11)
plt.ylabel('sales')
plt.ticklabel_format(style='plain', axis='y')
plt.yticks(np.arange(0, 10000, 1000))
plt.title('Yearly basis monthwise sales in qty', fontsize='15', fontweight='bold')
plt.show()

# %%
cust_order_item.head(5)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix customer_city  customer_state  \
# 0                     14409      Adilabad  Andhra Pradesh
# 1                      9790         Adoni  Andhra Pradesh
# 2                      1151  Akkarampalle  Andhra Pradesh
# 3                      8775   Akkayapalle  Andhra Pradesh
# 4                     13056         Alwal  Andhra Pradesh
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:00
# ...

# %%
# Mothwise sorting of cities from high to low qty sold
time_sales_location=cust_order_item.groupby(['year', 'month', 'customer_state', 'customer_city'])[['net_price', 'product_id']].agg({'net_price': 'sum', 'product_id': 'count'}).reset_index()
time_sales_location.columns=['year', 'month', 'customer_state', 'customer_city', 'revenue', 'qty']
time_sales_location=time_sales_location.sort_values(by=['year', 'month', 'qty'], ascending=[True, True, False], ignore_index= True)
time_sales_location
# Out:
#        year  month  customer_state customer_city  revenue  qty
# 0      2016      9  Andhra Pradesh      Kandukur   143.46    3
# 1      2016      9         Gujarat        Dholka   136.23    2
# 2      2016      9  Andhra Pradesh          Tuni    75.06    1
# 3      2016     10  Andhra Pradesh  Akkarampalle  4607.50   41
# 4      2016     10  Andhra Pradesh     Badepalle  7901.84   38
# ...     ...    ...             ...           ...      ...  ...
# 21394  2018      8     West Bengal       Panchla    69.69    1
# 21395  2018      8     West Bengal     Parashkol   112.77    1
# 21396  2018      8     West Bengal     Prayagpur   140.47    1
# 21397  2018      8     West Bengal      Titagarh    29.13    1
# 21398  2018      9  Andhra Pradesh  Akkarampalle   166.46    1
#
# [21399 rows x 6 columns]

# %%
# Mothwise sorting of state from high to low qty sold
time_state_sales=cust_order_item.groupby(['year', 'month', 'customer_state'])[['net_price', 'product_id']].agg({'net_price': 'sum', 'product_id': 'count'}).reset_index()
time_state_sales.columns=['year', 'month', 'customer_state', 'revenue', 'qty']
time_state_sales=time_state_sales.sort_values(by=['year', 'month', 'qty'], ascending=[True, True, False], ignore_index= True)
time_state_sales
# Out:
#      year  month    customer_state   revenue  qty
# 0    2016      9    Andhra Pradesh    218.52    4
# 1    2016      9           Gujarat    136.23    2
# 2    2016     10    Andhra Pradesh  34450.24  226
# 3    2016     10           Gujarat   5439.21   21
# 4    2016     10         Karnataka   2478.66   16
# ..    ...    ...               ...       ...  ...
# 404  2018      8  Himachal Pradesh   5052.80   46
# 405  2018      8            Punjab   7632.98   45
# 406  2018      8       West Bengal   3163.75   20
# 407  2018      8       Uttaranchal    501.57    3
# 408  2018      9    Andhra Pradesh    166.46    1
#
# [409 rows x 5 columns]

# %%
# Statewise revenue and qty sold, sorted in descending order of qty sold
sales_state=cust_order_item.groupby('customer_state')[['net_price', 'product_id']].agg({'net_price': 'sum', 'product_id': 'count'}).reset_index()
sales_state.columns=['customer_state', 'revenue', 'qty']
sales_state=sales_state.sort_values(by= 'qty', ascending= False, ignore_index= True)
sales_state
# Out:
#        customer_state     revenue    qty
# 0      Andhra Pradesh  9329513.16  69093
# 1             Gujarat  1246109.10   8499
# 2        Chhattisgarh  1076784.03   7106
# 3           Karnataka   624909.08   4345
# 4               Delhi   578251.81   3751
# 5      Madhya Pradesh   489237.77   3226
# 6             Haryana   352845.56   2488
# 7          Tamil Nadu   369377.50   2358
# 8         Maharashtra   332966.48   2246
# 9     Jammu & Kashmir   250429.96   1752
# 10             Kerala   245606.94   1709
# 11  Arunachal Pradesh   185467.27   1258
# 12      Uttar Pradesh   180920.80   1135
# 13          Rajasthan   147924.69    895
# 14   Himachal Pradesh   120783.25    837
# 15             Punjab   108157.44    741
# 16             Orissa   114667.76    677
# 17        West Bengal    72701.22    418
# 18        Uttaranchal    15909.59    106
# 19                Goa      989.83     10

# %%
# Citywise revenue and qty sold, sorted in descending order of qty sold
sales_city=cust_order_item.groupby('customer_city')[['net_price', 'product_id']].agg({'net_price': 'sum', 'product_id': 'count'}).reset_index()
sales_city.columns=['customer_city', 'revenue', 'qty']
sales_city=sales_city.sort_values(by= 'qty', ascending= False, ignore_index= True)
sales_city
# Out:
#       customer_city     revenue    qty
# 0      Akkarampalle  2170227.12  17808
# 1         Badepalle  1154234.02   7837
# 2         Anantapur   416733.39   3144
# 3      Eddumailaram   352305.14   2392
# 4        Anakapalle   244739.87   1751
# ...             ...         ...    ...
# 4105  Neripperichal      253.98      1
# 4106      Nepanagar      113.55      1
# 4107         Nemili      253.09      1
# 4108     Nelliyalam      105.28      1
# 4109        Marudur      173.95      1
#
# [4110 rows x 3 columns]

# %%
prod_cust_order_item = pd.merge(cust_order_item, products, 'inner', 'product_id')
prod_cust_order_item.drop(columns=['customer_zip_code_prefix', 'order_delivered_carrier_date', 'order_approved_at', 'shipping_limit_date', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm'], inplace= True)
prod_cust_order_item.head(2)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  8912fc0c3bbf1e2fbf35819e21706718  9eae34bbd3a474ec5d07949ca7de67c0
#
#   customer_city   customer_state                          order_id  \
# 0      Adilabad   Andhra Pradesh  00e7ee1b050b8499577073aeb2a297a1
# 1      Rehambal  Jammu & Kashmir  c1d2b34febe9cd269e378117d6681172
#
#   order_status order_purchase_timestamp order_delivered_customer_date  \
# 0    delivered      2017-05-16 15:05:00           2017-05-25 10:35:00
# 1    delivered      2017-11-09 00:50:00           2017-11-28 00:09:00
#
#   order_estimated_delivery_date  month  year  order_item_id  \
# 0                    2017-06-05      5  2017              1
# 1                    2017-12-19     11  2017              1
#
#                          product_id                         seller_id   price  \
# ...

# %%
# Categorywise revenue and qty sold, sorted in descending order of qty sold
category_sales=prod_cust_order_item.groupby('product_category_name')[['net_price', 'product_id']].agg({'net_price': 'sum', 'product_id': 'count'}).reset_index()
category_sales.columns=['product_category_name', 'revenue', 'qty']
category_sales=category_sales.sort_values(by= 'qty', ascending= False, ignore_index= True)
category_sales
# Out:
#         product_category_name     revenue    qty
# 0              Bed_Bath_Table  1241681.72  11115
# 1               Health_Beauty  1441248.07   9670
# 2              Sports_Leisure  1156656.48   8641
# 3             Furniture_Decor   902511.79   8334
# 4       Computers_Accessories  1059272.40   7827
# ..                        ...         ...    ...
# 66      Arts_And_Craftmanship     2184.14     24
# 67                 La_Cuisine     2388.54     14
# 68          Cds_Dvds_Musicals      954.99     14
# 69  Fashion_Childrens_Clothes      665.36      8
# 70      Security_And_Services      324.51      2
#
# [71 rows x 3 columns]

# %%
cust_payment_order = pd.merge(cust_order_item, order_Payments, 'inner', 'order_id')
cust_payment_order.drop(columns=['customer_zip_code_prefix', 'order_delivered_carrier_date', 'order_approved_at', 'shipping_limit_date'], inplace= True)
cust_payment_order.head(5)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#   customer_city  customer_state                          order_id  \
# 0      Adilabad  Andhra Pradesh  00e7ee1b050b8499577073aeb2a297a1
# 1         Adoni  Andhra Pradesh  29150127e6685892b6eab3eec79f59c7
# 2  Akkarampalle  Andhra Pradesh  b2059ed67ce144a36e2aa97d2c9e9ad2
# 3   Akkayapalle  Andhra Pradesh  951670f92359f4fe4a63112aa7306eba
# 4         Alwal  Andhra Pradesh  6b7d50bd145f6fc7f33cebabd7e49d0f
#
#   order_status order_purchase_timestamp order_delivered_customer_date  \
# 0    delivered      2017-05-16 15:05:00           2017-05-25 10:35:00
# ...

# %%
# Payment channel wise revenue and qty sold, sorted in descending order of qty sold
payment_method_sales=cust_payment_order.groupby('payment_type')[['net_price', 'product_id']].agg({'net_price': 'sum', 'product_id': 'count'}).reset_index()
payment_method_sales.columns=['payment_type', 'revenue', 'qty']
payment_method_sales=payment_method_sales.sort_values(by= 'qty', ascending= False, ignore_index= True)
payment_method_sales
# Out:
#   payment_type      revenue    qty
# 0  credit_card  12723914.88  86769
# 1          UPI   2842240.29  22867
# 2      voucher    785081.94   6274
# 3   debit_card    215306.74   1691

# %% [markdown]
# #### 1.f Popular Products by month, seller, state, category.

# %%
# Monthwise qty of products sold, sorted in descending order of qty sold
month_popular_product=prod_cust_order_item.groupby(['year', 'month', 'product_id'])[['product_id']].count().rename(columns={'product_id':'count'}).reset_index()
month_popular_product.sort_values(by=['year', 'month', 'count'], ascending=[True, True, False], ignore_index=True, inplace=True)
month_popular_product
# Out:
#        year  month                        product_id  count
# 0      2016      9  5a6b04657a4c5ee34285d1e4619a96b4      3
# 1      2016      9  c1488892604e4ba5cff5b4eb4d595400      1
# 2      2016      9  f293394c72c9b5fafd7023301fc21fc2      1
# 3      2016      9  f3c2d01a84c947b078e32bbef0718962      1
# 4      2016     10  eba7488e1c67729f045ab43fac426f2e     11
# ...     ...    ...                               ...    ...
# 62171  2018      8  ff96895c6b1d31f34b2d82f86670fa85      1
# 62172  2018      8  ffc9caf33e2d1e9f44e3e06da19085f7      1
# 62173  2018      8  ffd4bf4306745865e5692f69bd237893      1
# 62174  2018      8  ffd9ac56db9194a413298faaa03cd176      1
# 62175  2018      9  b98992ea80b467987a7fbb88e7f2076a      1
#
# [62176 rows x 4 columns]

# %%
# sellerwise most popular product and its qty sold
seller_popular_product=prod_cust_order_item.groupby(['seller_id', 'product_id'])[['product_id']].count().rename(columns={'product_id':'count'}).reset_index()
seller_popular_product=seller_popular_product.sort_values(by='count', ascending= False).drop_duplicates(subset='seller_id' ,keep='first').reset_index(drop=True)
seller_popular_product
# Out:
#                              seller_id                        product_id  \
# 0     955fee9216a65b617aa5c0531780ce60  aca2eb7d00ea1a7b8ebd4e68314663af
# 1     1f50f920176fa81dab994f9023523100  422879e10f46682990de24d770e7f83d
# 2     4a3ca9315b744ce9f8e9374361493884  99a4788cb24856965c36a24e339b6058
# 3     a1043bafd471dff536d0c462352beb48  d1c427060a0f73f6b889a5c7c61f2ac4
# 4     cc419e0650a3c5ba77189a1882b7556a  154e7e31ebfa092203795c972e5804a6
# ...                                ...                               ...
# 3090  70c0fda4c313d87115644d39e62eec60  41e4e4c8ab0ec1fcde0df5679749a3e4
# 3091  6ebf4eceee4dd9847201c82e77ef8123  33334a894aca4ac5b4b0832506727673
# 3092  6e85dc5ecd97a61094b89b046a509d8e  af0d0d1521e30e05b1cfc77192c685b6
# 3093  6dd7dce75cd55c1ce255dc38d9f0cd46  ea2dff335f794fa9a17e0be77a73d34d
# 3094  6e2d3e2dc84fb30f6078f39dd3bddd6f  d87ee5661dc46c5bc7bc19780f6f8360
#
#       count
# 0       527
# 1       484
# 2       482
# 3       343
# 4       281
# ...

# %%
# Categorywise most popular product and its qty sold
category_popular_product=prod_cust_order_item.groupby(['product_category_name', 'product_id'])[['product_id']].count().rename(columns={'product_id':'count'}).reset_index()
category_popular_product=category_popular_product.sort_values(by='count', ascending= False).drop_duplicates(subset='product_category_name' ,keep='first').reset_index(drop=True)
category_popular_product
# Out:
#         product_category_name                        product_id  count
# 0             Furniture_Decor  aca2eb7d00ea1a7b8ebd4e68314663af    527
# 1              Bed_Bath_Table  99a4788cb24856965c36a24e339b6058    488
# 2                Garden_Tools  422879e10f46682990de24d770e7f83d    484
# 3       Computers_Accessories  d1c427060a0f73f6b889a5c7c61f2ac4    343
# 4               Watches_Gifts  53b36df67ebb7c41585e8d54d6772e08    323
# ..                        ...                               ...    ...
# 66      Arts_And_Craftmanship  b9976e9c22fb1540bd71d1bcd2989475      5
# 67                      Music  4befae07dba4384f6d8237ad1e7f8294      4
# 68                 La_Cuisine  33900d427fa4bd3f509cdacda72e84a3      3
# 69  Fashion_Childrens_Clothes  57bdf3098169cccdb62221bd3e089cbd      3
# 70      Security_And_Services  8db75af9aed3315374db44d7860e25da      1
#
# [71 rows x 3 columns]

# %%
# Statewise most popular product and its qty sold
state_popular_product=prod_cust_order_item.groupby(['customer_state', 'product_id'])[['product_id']].count().rename(columns={'product_id':'count'}).reset_index()
state_popular_product=state_popular_product.sort_values(by='count', ascending= False).drop_duplicates(subset='customer_state' ,keep='first').reset_index(drop=True)
state_popular_product
# Out:
#        customer_state                        product_id  count
# 0      Andhra Pradesh  aca2eb7d00ea1a7b8ebd4e68314663af    345
# 1             Gujarat  53759a2ecddad2bb87a079a1f1519f73     45
# 2        Chhattisgarh  368c6c730842d78016ad823897a372db     40
# 3           Karnataka  422879e10f46682990de24d770e7f83d     24
# 4               Delhi  53759a2ecddad2bb87a079a1f1519f73     22
# 5      Madhya Pradesh  99a4788cb24856965c36a24e339b6058     17
# 6     Jammu & Kashmir  89b190a046022486c635022524a974a8     15
# 7          Tamil Nadu  99a4788cb24856965c36a24e339b6058     13
# 8              Kerala  aca2eb7d00ea1a7b8ebd4e68314663af     13
# 9             Haryana  2b4609f8948be18874494203496bc318     13
# 10        Maharashtra  99a4788cb24856965c36a24e339b6058     13
# 11  Arunachal Pradesh  03e1c946c0ddfc58724ff262aef08dff     12
# 12      Uttar Pradesh  3dd2a17168ec895c781a9191c1e95ad7      8
# 13          Rajasthan  368c6c730842d78016ad823897a372db      7
# ...

# %% [markdown]
# #### 1.f Popular categories by state, month

# %%
# Statewise most popular category and its qty sold
state_popular_category=prod_cust_order_item.groupby(['customer_state', 'product_category_name'])[['product_category_name']].count().rename(columns={'product_category_name':'count'}).reset_index()
state_popular_category=state_popular_category.sort_values(by='count', ascending= False).drop_duplicates(subset='customer_state' ,keep='first').reset_index(drop=True)
state_popular_category
# Out:
#        customer_state  product_category_name  count
# 0      Andhra Pradesh         Bed_Bath_Table   7101
# 1             Gujarat         Bed_Bath_Table    786
# 2        Chhattisgarh         Bed_Bath_Table    681
# 3           Karnataka         Bed_Bath_Table    379
# 4               Delhi          Health_Beauty    328
# 5      Madhya Pradesh         Bed_Bath_Table    319
# 6             Haryana         Bed_Bath_Table    282
# 7         Maharashtra         Bed_Bath_Table    213
# 8          Tamil Nadu         Bed_Bath_Table    212
# 9     Jammu & Kashmir         Bed_Bath_Table    160
# 10             Kerala         Bed_Bath_Table    146
# 11  Arunachal Pradesh         Bed_Bath_Table    114
# 12      Uttar Pradesh          Health_Beauty    104
# 13          Rajasthan         Sports_Leisure     97
# 14   Himachal Pradesh         Bed_Bath_Table     83
# 15             Orissa         Bed_Bath_Table     79
# 16             Punjab          Health_Beauty     72
# ...

# %%
# Monthwise most popular category and its qty sold
month_popular_category=prod_cust_order_item.groupby(['year', 'month', 'product_category_name'])[['product_category_name']].count().rename(columns={'product_category_name':'count'}).reset_index()
month_popular_category=month_popular_category.sort_values(by=['year', 'month', 'count'], ascending= [True, True, False]).drop_duplicates(subset=['year', 'month'] ,keep='first').reset_index(drop=True)
month_popular_category
# Out:
#     year  month                    product_category_name  count
# 0   2016      9                            Health_Beauty      3
# 1   2016     10                          Furniture_Decor     67
# 2   2016     12                 Fashion_Bags_Accessories      1
# 3   2017      1                          Furniture_Decor    182
# 4   2017      2                          Furniture_Decor    266
# 5   2017      3                          Furniture_Decor    328
# 6   2017      4                           Bed_Bath_Table    274
# 7   2017      5                           Bed_Bath_Table    369
# 8   2017      6                           Bed_Bath_Table    382
# 9   2017      7                           Bed_Bath_Table    579
# 10  2017      8                           Bed_Bath_Table    512
# 11  2017      9                           Bed_Bath_Table    533
# 12  2017     10                           Bed_Bath_Table    545
# 13  2017     11                           Bed_Bath_Table    975
# ...

# %% [markdown]
# #### 1.h  List top 10 most expensive products sorted by price

# %%
Top_10_expensive_prod=order_items.loc[:, ['product_id', 'price']].drop_duplicates(subset='product_id' ).sort_values(by='price',ascending = False).head(10).reset_index(drop=True)
Top_10_expensive_prod
# Out:
#                          product_id    price
# 0  489ae2aa008f021502940f251d4cce7f  6735.00
# 1  69c590f7ffc7bf8db97190b6cb6ed62e  6729.00
# 2  1bdf5e6731585cf01aa8169c7028d6ad  6499.00
# 3  a6492cc69376c469ab6f61d8f44de961  4799.00
# 4  c3ed642d592594bb648ff4a04cee2747  4690.00
# 5  259037a6a41845e455183f89c5035f18  4590.00
# 6  a1beef8f3992dbd4cd8726796aa69c53  4399.87
# 7  6cdf8fc1d741c76586d8b6b15e9eef30  4099.99
# 8  6902c1962dd19d540807d0ab8fade5c6  3999.90
# 9  4ca7b91a31637bd24fb8e559d5e015e4  3999.00

# %% [markdown]
# #### Q2 Performing Customers/sellers Segmentation
# #### 2.a Divide the customers into groups based on the revenue generated

# %%
cust_revenue=prod_cust_order_item.groupby('customer_unique_id')['net_price'].sum().reset_index().rename(columns={'net_price' : 'amount_spend'})
cust_revenue
# Out:
#                      customer_unique_id  amount_spend
# 0      0000366f3b9a7992bf8c76cfdf3221e2        141.90
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f         27.19
# 2      0000f46a3911fa3c0805444483337064         86.22
# 3      0000f6ccb0745a6a4b88665a16c9f078         43.62
# 4      0004aac84e0df4da2b147fca70cf8255        196.89
# ...                                 ...           ...
# 95415  fffcf5a5ff07b0908bd4e2dbc735a684       2067.42
# 95416  fffea47cd6d3cc0a88bd621562a9d061         84.58
# 95417  ffff371b4d645b6ecea244b27531430a        112.46
# 95418  ffff5962728ec6157033ef9805bacc48        133.69
# 95419  ffffd2657e2aad2907e67c3e9daecbeb         71.56
#
# [95420 rows x 2 columns]

# %%
cust_revenue['cust_group']=pd.cut(cust_revenue.amount_spend, bins= np.arange(0 , 22000, 2000),
                               labels=['0-2000','2000-4000','4000-6000','6000-8000',
                                       '8000-10000','10000-12000','12000-14000','14000-16000','16000-18000',
                                      '18000-20000'])
cust_revenue
# Out:
#                      customer_unique_id  amount_spend cust_group
# 0      0000366f3b9a7992bf8c76cfdf3221e2        141.90     0-2000
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f         27.19     0-2000
# 2      0000f46a3911fa3c0805444483337064         86.22     0-2000
# 3      0000f6ccb0745a6a4b88665a16c9f078         43.62     0-2000
# 4      0004aac84e0df4da2b147fca70cf8255        196.89     0-2000
# ...                                 ...           ...        ...
# 95415  fffcf5a5ff07b0908bd4e2dbc735a684       2067.42  2000-4000
# 95416  fffea47cd6d3cc0a88bd621562a9d061         84.58     0-2000
# 95417  ffff371b4d645b6ecea244b27531430a        112.46     0-2000
# 95418  ffff5962728ec6157033ef9805bacc48        133.69     0-2000
# 95419  ffffd2657e2aad2907e67c3e9daecbeb         71.56     0-2000
#
# [95420 rows x 3 columns]

# %% [markdown]
# #### 2.b Divide the sellers into groups based on the revenue generated

# %%
seller_revenue=prod_cust_order_item.groupby('seller_id')['net_price'].sum().reset_index().rename(columns={'net_price' : 'revenue_gen'})
seller_revenue
# Out:
#                              seller_id  revenue_gen
# 0     0015a82c2db000af6aaaf3ae2ecb0532      2748.06
# 1     001cca7ae9ae17fb1caed9dfb1094831     33934.17
# 2     001e6ad469a905060d959994f1b41e4f       267.94
# 3     002100f778ceb8431b7a1020ff7ab48f      2028.16
# 4     003554e2dce176b5555353e4f3555ac8       139.38
# ...                                ...          ...
# 3090  ffcfefa19b08742c5d315f2791395ee5        79.52
# 3091  ffdd9f82b9a447f6f8d4b91554cc7dd3      2828.66
# 3092  ffeee66ac5d5a62fe688b9d26f83f534      2259.55
# 3093  fffd5413c0700ac820c7069d66d98c89     11896.04
# 3094  ffff564a4f9085cd26170f4732393726      1770.86
#
# [3095 rows x 2 columns]

# %%
seller_revenue.revenue_gen.max()
# Out:
# 249640.7

# %%
seller_revenue['seller_group']=pd.cut(seller_revenue.revenue_gen, bins= np.arange(0 , 330000, 30000),
                               labels=['0-30000','30000-60000','60000-90000','90000-120000','120000-150000',
                                       '150000-180000', '180000-210000', '210000-240000', '240000-270000', '270000-300000'])
seller_revenue
# Out:
#                              seller_id  revenue_gen seller_group
# 0     0015a82c2db000af6aaaf3ae2ecb0532      2748.06      0-30000
# 1     001cca7ae9ae17fb1caed9dfb1094831     33934.17  30000-60000
# 2     001e6ad469a905060d959994f1b41e4f       267.94      0-30000
# 3     002100f778ceb8431b7a1020ff7ab48f      2028.16      0-30000
# 4     003554e2dce176b5555353e4f3555ac8       139.38      0-30000
# ...                                ...          ...          ...
# 3090  ffcfefa19b08742c5d315f2791395ee5        79.52      0-30000
# 3091  ffdd9f82b9a447f6f8d4b91554cc7dd3      2828.66      0-30000
# 3092  ffeee66ac5d5a62fe688b9d26f83f534      2259.55      0-30000
# 3093  fffd5413c0700ac820c7069d66d98c89     11896.04      0-30000
# 3094  ffff564a4f9085cd26170f4732393726      1770.86      0-30000
#
# [3095 rows x 3 columns]

# %% [markdown]
# #### Q3 Cross-Selling (Which products are selling together)

# %%
cross_selling = prod_cust_order_item[prod_cust_order_item.duplicated(['order_purchase_timestamp','customer_id'],
                                                                 keep=False)].sort_values(by='order_purchase_timestamp')
cross_selling = cross_selling.loc[:,['customer_id','order_purchase_timestamp','product_id' ]]

cross_selling.drop_duplicates(subset ="product_id" ,inplace=True)
cross_selling = cross_selling[cross_selling.duplicated(['order_purchase_timestamp','customer_id'],
                                                       keep=False)].sort_values(by='order_purchase_timestamp').reset_index()
cross_selling.drop(columns = 'index',axis=1, inplace=True)

print('Products with same customer id and order purchase timestamp are cross selling')
cross_selling
# Out:
# Products with same customer id and order purchase timestamp are cross selling
#                            customer_id order_purchase_timestamp  \
# 0     08c5351a6aca1c1589a38f244edeee9d      2016-09-04 21:15:00
# 1     08c5351a6aca1c1589a38f244edeee9d      2016-09-04 21:15:00
# 2     a0f95ab56c6d3a5ba0036b7fdfeda07f      2016-10-04 15:02:00
# 3     a0f95ab56c6d3a5ba0036b7fdfeda07f      2016-10-04 15:02:00
# 4     00474d2582fd72663036795b7ab8cfc1      2016-10-04 22:33:00
# ...                                ...                      ...
# 3566  72a366446dd3abfc90c598896714d85c      2018-08-26 11:02:00
# 3567  e5a8aaccb766e00177b0a587979cc814      2018-08-26 11:44:00
# 3568  e5a8aaccb766e00177b0a587979cc814      2018-08-26 11:44:00
# 3569  c24bbeb8111fea27eab791a37e665210      2018-08-27 12:39:00
# 3570  c24bbeb8111fea27eab791a37e665210      2018-08-27 12:39:00
#
#                             product_id
# 0     c1488892604e4ba5cff5b4eb4d595400
# 1     f293394c72c9b5fafd7023301fc21fc2
# ...

# %% [markdown]
# #### Q4 Payment Behaviour
# #### 4.a How customers are paying?

# %%
cust_payment_order.head(2)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
#
#   customer_city  customer_state                          order_id  \
# 0      Adilabad  Andhra Pradesh  00e7ee1b050b8499577073aeb2a297a1
# 1         Adoni  Andhra Pradesh  29150127e6685892b6eab3eec79f59c7
#
#   order_status order_purchase_timestamp order_delivered_customer_date  \
# 0    delivered      2017-05-16 15:05:00           2017-05-25 10:35:00
# 1    delivered      2018-01-12 20:48:00           2018-01-29 12:41:00
#
#   order_estimated_delivery_date  month  ...  order_item_id  \
# 0                    2017-06-05      5  ...              1
# 1                    2018-02-06      1  ...              1
#
#                          product_id                         seller_id   price  \
# ...

# %%
cust_payment_mode = cust_payment_order.payment_type.drop_duplicates().reset_index().drop(columns = 'index')
print('Customers are paying by Credit cards, UPIs, Vouchers and Debit cards.')
cust_payment_mode
# Out:
# Customers are paying by Credit cards, UPIs, Vouchers and Debit cards.
#   payment_type
# 0  credit_card
# 1   debit_card
# 2      voucher
# 3          UPI

# %% [markdown]
# #### 4.b Which payment channels are used by most customers?

# %%
cust_popular_payment_mode = cust_payment_order.groupby('payment_type')[['payment_type']].count().rename(columns={'payment_type' : 'No_of_transactions'}).sort_values(by='No_of_transactions', ascending= False).reset_index()
print('Credit card and upi are the most popular payment channels')
cust_popular_payment_mode
# Out:
# Credit card and upi are the most popular payment channels
#   payment_type  No_of_transactions
# 0  credit_card               86769
# 1          UPI               22867
# 2      voucher                6274
# 3   debit_card                1691

# %% [markdown]
# #### Q5 Customer satisfaction towards category & product
# #### 5.a Which categories (top 10) are maximum rated & minimum rated?

# %%
order_items_prod_review = pd.merge(prod_cust_order_item, order_review_ratings ,how= 'left', on = 'order_id')
category_review=order_items_prod_review.groupby('product_category_name')[['review_score']].sum()
category_review.head(5)
# Out:
#                             review_score
# product_category_name
# Agro_Industry_And_Commerce           848
# Air_Conditioning                    1164
# Art                                  819
# Arts_And_Craftmanship                 99
# Audio                               1390

# %%
# Top 10 maximum rated product categories
max_cat_review=category_review.sort_values(by='review_score', ascending = False).head(10).reset_index()
print('Top 10 maximum rated product categories :')
max_cat_review
# Out:
# Top 10 maximum rated product categories :
#    product_category_name  review_score
# 0         Bed_Bath_Table         43636
# 1          Health_Beauty         40121
# 2         Sports_Leisure         35616
# 3        Furniture_Decor         32716
# 4  Computers_Accessories         30953
# 5             Housewares         28235
# 6          Watches_Gifts         24016
# 7              Telephony         17907
# 8           Garden_Tools         17572
# 9                   Auto         17193

# %%
# Top 10 minimum rated product categories
min_cat_review=category_review.sort_values(by='review_score', ascending = True).head(10).reset_index()
print('Top 10 minimum rated product categories :')
min_cat_review
# Out:
# Top 10 minimum rated product categories :
#                product_category_name  review_score
# 0              Security_And_Services             5
# 1          Fashion_Childrens_Clothes            36
# 2                         La_Cuisine            53
# 3                  Cds_Dvds_Musicals            65
# 4              Arts_And_Craftmanship            99
# 5                     Home_Comfort_2           101
# 6                Diapers_And_Hygiene           127
# 7                      Fashion_Sport           132
# 8                            Flowers           139
# 9  Furniture_Mattress_And_Upholstery           145

# %% [markdown]
# #### 5.b Which products (top10) are maximum rated & minimum rated?

# %%
# Top 10 maximum rated products
product_review=order_items_prod_review.groupby('product_id')[['review_score']].sum()
max_product_review=product_review.sort_values(by='review_score', ascending = False).head(10).reset_index()
print('Top 10 maximum rated product :')
max_product_review
# Out:
# Top 10 maximum rated product :
#                          product_id  review_score
# 0  aca2eb7d00ea1a7b8ebd4e68314663af          2112
# 1  422879e10f46682990de24d770e7f83d          1920
# 2  99a4788cb24856965c36a24e339b6058          1896
# 3  389d119b48cf3043d311335e499d9c6b          1612
# 4  368c6c730842d78016ad823897a372db          1531
# 5  53759a2ecddad2bb87a079a1f1519f73          1448
# 6  d1c427060a0f73f6b889a5c7c61f2ac4          1432
# 7  53b36df67ebb7c41585e8d54d6772e08          1348
# 8  154e7e31ebfa092203795c972e5804a6          1264
# 9  3dd2a17168ec895c781a9191c1e95ad7          1147

# %%
# Top 10 minimum rated product
min_product_review=product_review.sort_values(by='review_score', ascending = True).head(10).reset_index()
print('Top 10 minimum rated product :')
min_product_review
# Out:
# Top 10 minimum rated product :
#                          product_id  review_score
# 0  e03071a2d2410c9ef2be47b508cac95f             1
# 1  b56ff361e0733eebc1d010432936b706             1
# 2  7ed8c74b7ad2f1790a24a24c071da537             1
# 3  43c81702c9aca96af077286a5b2525b9             1
# 4  1da4613d4f7e10e1554538b46dd16486             1
# 5  ed9d81a5043f74cbe0e3db315770af45             1
# 6  5096e827f6152df3974343e735a52dc9             1
# 7  1da0fbb35cfdc9fcb6d48dfddca69513             1
# 8  1d9c9e0532fb481c0f89c3b20cec62e6             1
# 9  8ec6aedf40e1175c5446134c40931706             1

# %% [markdown]
# #### 5.c Average rating by location, product, category, seller, month etc.

# %%
# Average rating by location
avg_rating_location = order_items_prod_review.groupby('customer_state')['review_score'].mean().reset_index()
avg_rating_location.rename(columns={'customer_state':'Location', 'review_score':'Avg_review'}, inplace =True)
avg_rating_location
# Out:
#              Location  Avg_review
# 0      Andhra Pradesh    3.995915
# 1   Arunachal Pradesh    4.040094
# 2        Chhattisgarh    4.032326
# 3               Delhi    4.034529
# 4                 Goa    4.800000
# 5             Gujarat    4.033353
# 6             Haryana    4.110356
# 7    Himachal Pradesh    3.998812
# 8     Jammu & Kashmir    4.015873
# 9           Karnataka    4.010731
# 10             Kerala    4.051774
# 11     Madhya Pradesh    4.009870
# 12        Maharashtra    4.083925
# 13             Orissa    4.100295
# 14             Punjab    4.159732
# 15          Rajasthan    4.121381
# 16         Tamil Nadu    4.105063
# 17      Uttar Pradesh    4.138840
# 18        Uttaranchal    3.698113
# 19        West Bengal    4.002392

# %%
# Average rating by seller
avg_rating_seller = order_items_prod_review.groupby('seller_id')['review_score'].mean().reset_index()
avg_rating_seller.rename(columns={'review_score':'Avg_review'}, inplace =True)
avg_rating_seller
# Out:
#                              seller_id  Avg_review
# 0     0015a82c2db000af6aaaf3ae2ecb0532    3.666667
# 1     001cca7ae9ae17fb1caed9dfb1094831    3.874477
# 2     001e6ad469a905060d959994f1b41e4f    1.000000
# 3     002100f778ceb8431b7a1020ff7ab48f    3.982143
# 4     003554e2dce176b5555353e4f3555ac8    5.000000
# ...                                ...         ...
# 3090  ffcfefa19b08742c5d315f2791395ee5    1.000000
# 3091  ffdd9f82b9a447f6f8d4b91554cc7dd3    4.250000
# 3092  ffeee66ac5d5a62fe688b9d26f83f534    4.214286
# 3093  fffd5413c0700ac820c7069d66d98c89    3.885246
# 3094  ffff564a4f9085cd26170f4732393726    2.100000
#
# [3095 rows x 2 columns]

# %%
# Average rating by product
avg_rating_product = order_items_prod_review.groupby('product_id')['review_score'].mean().reset_index()
avg_rating_product.rename(columns={'review_score':'Avg_review'}, inplace =True)
avg_rating_product
# Out:
#                              product_id  Avg_review
# 0      00066f42aeeb9f3007548bb9d3f33c38         5.0
# 1      00088930e925c41fd95ebfe695fd2655         4.0
# 2      0009406fd7479715e4bef61dd91f2462         1.0
# 3      000b8f95fcb9e0096488278317764d19         5.0
# 4      000d9be29b5207b54e86aa1b1ac54872         5.0
# ...                                 ...         ...
# 32946  fff6177642830a9a94a0f2cba5e476d1         4.5
# 32947  fff81cc3158d2725c0655ab9ba0f712c         4.0
# 32948  fff9553ac224cec9d15d49f5a263411f         5.0
# 32949  fffdb2d0ec8d6a61f0a0a0db3f25b441         5.0
# 32950  fffe9eeff12fcbd74a2f2b007dde0c58         4.0
#
# [32951 rows x 2 columns]

# %%
# Average rating by product
avg_rating_category = order_items_prod_review.groupby('product_category_name')['review_score'].mean().reset_index()
avg_rating_category.rename(columns={'review_score':'Avg_review'}, inplace =True)
avg_rating_category
# Out:
#          product_category_name  Avg_review
# 0   Agro_Industry_And_Commerce    4.000000
# 1             Air_Conditioning    3.919192
# 2                          Art    3.918660
# 3        Arts_And_Craftmanship    4.125000
# 4                        Audio    3.808219
# ..                         ...         ...
# 66                  Stationery    4.181386
# 67      Tablets_Printing_Image    4.048193
# 68                   Telephony    3.935604
# 69                        Toys    4.138667
# 70               Watches_Gifts    4.002000
#
# [71 rows x 2 columns]

# %%
# Average rating by product
avg_rating_month = order_items_prod_review.groupby(['year', 'month'])['review_score'].mean().reset_index()
avg_rating_month.rename(columns={'review_score':'Avg_review'}, inplace =True)
avg_rating_month
# Out:
#     year  month  Avg_review
# 0   2016      9    1.000000
# 1   2016     10    3.567935
# 2   2016     12    5.000000
# 3   2017      1    4.052795
# 4   2017      2    4.042813
# 5   2017      3    4.041722
# 6   2017      4    3.987375
# 7   2017      5    4.118364
# 8   2017      6    4.118265
# 9   2017      7    4.126835
# 10  2017      8    4.193997
# 11  2017      9    4.123510
# 12  2017     10    4.041162
# 13  2017     11    3.830450
# 14  2017     12    3.941139
# 15  2018      1    3.932470
# 16  2018      2    3.718585
# 17  2018      3    3.676709
# 18  2018      4    4.059972
# 19  2018      5    4.119723
# 20  2018      6    4.176595
# 21  2018      7    4.212087
# 22  2018      8    4.206897
# 23  2018      9    1.000000
